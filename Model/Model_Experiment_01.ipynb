# %% [markdown]
# # Model Experiment 01
#
# This notebook was created for experiment and research purposes in software engineering and software performance analyzis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carga del conjunto de datos de entrenamiento

# %%
df = pd.read_csv("../Data/code_metrics.csv")

# %% [markdown]
# ## Observación de los datos

# %%
df.head()
# Out:
#     LOC   n1    n2    N1    N2     n      N           V         L         D  \
# 0  11.0  6.0  26.0  18.0  39.0  32.0   57.0  285.000000  0.222222  4.500000
# 1  13.0  4.0  25.0  21.0  45.0  29.0   66.0  320.626746  0.277778  3.600000
# 2  23.0  6.0  35.0  30.0  71.0  41.0  101.0  541.112752  0.164319  6.085714
# 3  14.0  7.0  25.0  21.0  43.0  32.0   64.0  320.000000  0.166113  6.020000
# 4  18.0  6.0  28.0  25.0  56.0  34.0   81.0  412.084490  0.166667  6.000000
#
#              E         B
# 0  1282.500000  0.095000
# 1  1154.256284  0.106876
# 2  3293.057608  0.180371
# 3  1926.400000  0.106667
# 4  2472.506941  0.137361

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LOC     5 non-null      float64
#  1   n1      5 non-null      float64
#  2   n2      5 non-null      float64
#  3   N1      5 non-null      float64
#  4   N2      5 non-null      float64
#  5   n       5 non-null      float64
#  6   N       5 non-null      float64
#  7   V       5 non-null      float64
#  8   L       5 non-null      float64
#  9   D       5 non-null      float64
#  10  E       5 non-null      float64
#  11  B       5 non-null      float64
# dtypes: float64(12)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#              LOC        n1         n2         N1         N2          n  \
# count   5.000000  5.000000   5.000000   5.000000   5.000000   5.000000
# mean   15.800000  5.800000  27.800000  23.000000  50.800000  33.600000
# std     4.764452  1.095445   4.207137   4.636809  12.930584   4.505552
# min    11.000000  4.000000  25.000000  18.000000  39.000000  29.000000
# 25%    13.000000  6.000000  25.000000  21.000000  43.000000  32.000000
# 50%    14.000000  6.000000  26.000000  21.000000  45.000000  32.000000
# 75%    18.000000  6.000000  28.000000  25.000000  56.000000  34.000000
# max    23.000000  7.000000  35.000000  30.000000  71.000000  41.000000
#
#                N           V         L         D            E         B
# count    5.00000    5.000000  5.000000  5.000000     5.000000  5.000000
# mean    73.80000  375.764798  0.199420  5.241143  2025.744167  0.125255
# std     17.54138  103.739135  0.050185  1.133405   884.230261  0.034580
# ...

# %%
df.hist(bins=50, figsize=(12,8)) 
plt.show()

# %%
sns.pairplot(df)
